# %% [markdown]
# ### Solver de cuadrado magico usando backtracking

# %%
contador=0

def is_valid(grid, row, col, num,size): #verifica si el numero está disponible
    '''
    for x in range(size): # coordenada de la columna
        if grid[row][x] == num or grid[x][col] == num: # verificacion doble para buscar si num existe en horizontal o vertical
            return False
    '''
    
    #start_row = row - row % 3 
    #start_col = col - col % 3 # reseteo las coordenadas del cuadrante
    start_row=0
    start_col=0
    for i in range(size):
        for j in range(size): # en este bucle anidado verifico si num existe en la matriz 3x3
            if grid[i + start_row][j + start_col] == num:
                return False
    
    return True

def add_ok(grid, row, col, num,size):
    pass
    
    
    if sum(grid[row])==12 and grid[0][col]+ grid[1][col]+ grid[2][col]==12:
        return True
    return False
grid1=[
    [3,9,9],
    [9,4,9],
    [9,6,5],
]

size=len(grid1[0])

def solve_magic(grid,size):
    global contador
    
    for row in range(size): # contador que recorre uno a uno los elementos de la fila
        for col in range(size): # contador  que recorre uno a uno los elementos de la columna
            if grid[row][col] == 0: # si el espacio esta vacio, intente llenarlo
                for num in range(0, 9): #lista de todos los posibles valores para llenar el espacio
                    if is_valid(grid, row, col, num,size): # row,col coordenadas # retorna si se puede usar el numero
                        grid[row][col] = num
                        if add_ok(grid, row, col, num,size):
                            
                            contador+=1 # cuenta cuantas veces puso un nuemro en una posicion
                            if solve_magic(grid,size): # en al llamada recursiva se evalua el siguiente 0 en la fila
                                return True
                            grid[row][col] = 0 # si no funciona borra TODO lo que hizo en al llamada recursiva
                return False
        
    
    
    
    return True



if solve_magic(grid1,size):
    for row in grid1:
        print(row)
else:
    print("No solution found")

print(f"para este cuadrado magico el backtraking intento {contador} posibles soluciones")

# %%
def is_valid(board, row, col, num):
    # Verificar si el número ya está en la fila
    for i in range(3):
        if board[row][i] == num:
            return False

    # Verificar si el número ya está en la columna
    for i in range(3):
        if board[i][col] == num:
            return False

    # Verificar si el número ya está en la diagonal
    if row == col:
        for i in range(3):
            if board[i][i] == num:
                return False

    # Verificar si el número ya está en la diagonal secundaria
    if row + col == 2:
        for i in range(3):
            if board[i][2 - i] == num:
                return False

    return True


def solve_magic_square(board, row, col):
    # Si se ha completado el tablero
    if row == 3:
        return True

    # Si se ha completado la fila
    if col == 3:
        return solve_magic_square(board, row + 1, 0)

    # Si la posición actual ya está ocupada
    if board[row][col] != 0:
        return solve_magic_square(board, row, col + 1)

    for num in range(0, 9):
        if is_valid(board, row, col, num):
            board[row][col] = num

            # Intentar resolver el siguiente espacio en el tablero
            if solve_magic_square(board, row, col + 1):
                return True

            # Deshacer la elección si no se puede resolver el tablero
            board[row][col] = 9

    return False


def print_board(board):
    for row in board:
        print(row)


def main():
    board =[
    [3,9,9],
    [9,4,9],
    [9,6,5],
]

    if solve_magic_square(board, 0, 0):
        print("Cuadrado mágico:")
        print_board(board)
    else:
        print("No se pudo resolver el cuadrado mágico.")


if __name__ == "__main__":
    main()

# %%
def is_valid(board, row, col, num):
    return (
        0 <= row < 3
        and 0 <= col < 3
        and board[row][col] == 0
        and sum(board[i][col] for i in range(3)) + num == 12
        and sum(board[row][i] for i in range(3)) + num == 12
    )


def solve_magic_square(board, row, col):
    if row == 3:
        return True

    if col == 3:
        return solve_magic_square(board, row + 1, 0)

    for num in range(0,8,1):
        if is_valid(board, row, col, num):
            board[row][col] = num

            if solve_magic_square(board, row, col + 1):
                return True

            board[row][col] = 9

    return False


def print_board(board):
    for row in board:
        print(row)


def main():
    grid = [
        [3,9,9],
        [9,4,9],
        [9,6,9],
    ]

    if solve_magic_square(grid, 0, 0):
        print("Cuadrado mágico:")
        print_board(grid)
    else:
        print("No se pudo resolver el cuadrado mágico.")


if __name__ == "__main__":
    main()

# %%
import random

def is_valid(grid, row, col, num):
    # Verificar si el número ya existe en la fila
    for i in range(3):
        if grid[row][i] == num:
            return False

    # Verificar si el número ya existe en la columna
    for i in range(3):
        if grid[i][col] == num:
            return False

    # Verificar si el número ya existe en la diagonal principal
    if row == col:
        for i in range(3):
            if grid[i][i] == num:
                return False

    # Verificar si el número ya existe en la diagonal invertida
    if row + col == 2:
        for i in range(3):
            if grid[i][2 - i] == num:
                return False

    return True

def solve_magic_square(grid):
    for row in range(3):
        for col in range(3):
            if grid[row][col] == 9:
                for num in range(1, 9):
                    if is_valid(grid, row, col, num):
                        grid[row][col] = num

                        if solve_magic_square(grid):
                            return True

                        grid[row][col] = 9  # Deshacer la asignación

                return False
    print(grid)
    # Verificar si la matriz cumple con las condiciones
    for row in range(3):
        if sum(grid[row]) != 12:
            return False

    for col in range(3):
        if sum(grid[i][col] for i in range(3)) != 12:
            return False

    if sum(grid[i][i] for i in range(3)) != 12:
        return False

    if sum(grid[i][2 - i] for i in range(3)) != 12:
        return False

    return True


def main():
   
    grid = [
        [3,9,9],
        [9,4,9],
        [9,6,9],
    ]
    
    
    print("Matriz original:")
    for row in grid:
        print(row)

    if solve_magic_square(grid):
        print("\nMatriz solucionada:")
        for row in grid:
            print(row)
    else:
        print("\nNo se pudo resolver la matriz.")

if __name__ == "__main__":
    main()

# %%
def is_valid(grid, num, row, col):
    # Verifica si el número ya está en la fila o columna
    for i in range(3):
        if grid[row][i] == num or grid[i][col] == num:
            return False

    # Verifica la suma de la diagonal principal
    if row == col and sum(grid[i][i] for i in range(3)) + num != 12:
        return False

    # Verifica la suma de la diagonal inversa
    if row + col == 2 and sum(grid[i][2 - i] for i in range(3)) + num != 12:
        return False

    return True

def solve(grid):
    empty = find_empty(grid)
    if not empty:
        return True  # Todas las celdas están llenas, el cuadrado está resuelto

    row, col = empty

    for num in range(0, 9):
        if is_valid(grid, num, row, col):
            grid[row][col] = num
            print(grid)
            if solve(grid):
                return True  # Se encontró una solución

            grid[row][col] = 9  # Si no lleva a una solución, retrocede

    return False  # No hay solución con la configuración actual

def find_empty(grid):
    for i in range(3):
        for j in range(3):
            if grid[i][j] == 9:
                return (i, j)
    return None

grid = [
    [3, 9, 9],
    [9, 4, 9],
    [9, 6, 9],
]

solve(grid)

  
print("Matriz original:")
for row in grid:
    print(row)

if solve(grid):
    print("\nMatriz solucionada:")
    for row in grid:
        print(row)
else:
    print("\nNo se pudo resolver la matriz.")

# %%
def is_valid(grid, row, col, num):
    # check the number in the row
    for i in range(3):
        if grid[row][i] == num:
            return False

    # check the number in the column
    for i in range(3):
        if grid[i][col] == num:
            return False

    # check the number in the box
    start_row, start_col = row - row % 3, col - col % 3
    for i in range(3):
        for j in range(3):
            if grid[i + start_row][j + start_col] == num:
                return False

    return True


def solve_magic_square(grid):
    for i in range(3):
        for j in range(3):
            if grid[i][j] == 9:
                for num in range(0, 9):
                    if is_valid(grid, i, j, num):
                        grid[i][j] = num
                        print (grid)
                        if solve_magic_square(grid):
                            return True

                        grid[i][j] = 9  # undo the move

                        return False

    return True


def print_magic_square(grid):
    for row in grid:
        print(row)


grid = [
    [3, 9, 9],
    [9, 4, 9],
    [9, 6, 9],
]

if solve_magic_square(grid):
    print("Solution:")
    print_magic_square(grid)
else:
    print("No solution found.")

# %%
def is_valid(grid, num, row, col):
    # Verifica si el número ya está en la fila o columna
    for i in range(3):
        if grid[row][i] == num or grid[i][col] == num:
            return False

    # Verifica la suma de la diagonal principal
    if row == col and sum(grid[i][i] for i in range(3)) + num != 12:
        return False

    # Verifica la suma de la diagonal inversa
    if row + col == 2 and sum(grid[i][2 - i] for i in range(3)) + num != 12:
        return False

    return True

def solve(grid):
    empty = find_empty(grid)
    if not empty:
        return True  # Todas las celdas están llenas, el cuadrado está resuelto

    row, col = empty

    # Verifica si tiene dos casillas consecutivas con valores diferentes a 9
    if has_consecutive(grid, row, col):
        for num in range(0, 9):
            if is_valid(grid, num, row, col):
                grid[row][col] = num

                if solve(grid):
                    return True  # Se encontró una solución

                grid[row][col] = 9  # Si no lleva a una solución, retrocede

    return False  # No hay solución con la configuración actual

def find_empty(grid):
    for i in range(3):
        for j in range(3):
            if grid[i][j] == 9:
                return (i, j)
    return None

def has_consecutive(grid, row, col):
    # Verifica si tiene dos casillas consecutivas con valores diferentes a 9
    return ((grid[row].count(9) >= 2 and grid[row][col] == 9 and grid[row][(col + 1) % 3] != 9) or
            ([grid[i][col] for i in range(3)].count(9) >= 2 and grid[row][col] == 9 and grid[(row + 1) % 3][col] != 9) or
            (row == col and [grid[i][i] for i in range(3)].count(9) >= 2 and grid[row][col] == 9 and grid[(row + 1) % 3][(col + 1) % 3] != 9) or
            (row + col == 2 and [grid[i][2 - i] for i in range(3)].count(9) >= 2 and grid[row][col] == 9 and grid[(row + 1) % 3][(col - 1) % 3] != 9))

grid = [
    [3, 9, 9],
    [9, 4, 9],
    [9, 6, 9],
]

solve(grid)

# Imprime el cuadrado mágico resuelto
print("Matriz original:")
for row in grid:
    print(row)

if solve(grid):
    print("\nMatriz solucionada:")
    for row in grid:
        print(row)
else:
    print("\nNo se pudo resolver la matriz.")

# %%
def has_consecutive_in_row(grid, row, col):
    # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la misma fila
    return grid[row].count(9) <= 2 and grid[row][col] == 9 and 9 not in grid[row][:col] + grid[row][col + 1:]

def has_consecutive_in_column(grid, row, col):
    # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la misma columna
    column_values = [grid[i][col] for i in range(3)]
    '''
    print(column_values)
    print("column_values.count(9) >= 2 \n", column_values.count(9) >= 2)
    print("grid[row][col] == 9 \n",grid[row][col] == 9)
    print("9 not in column_values[:row] + column_values[row + 1:]\n",9 not in column_values[:row] + column_values[row + 1:])
    '''
   
    return column_values.count(9) <= 2 and grid[row][col] == 9 and 9 not in column_values[:row] + column_values[row + 1:]

def has_consecutive_in_main_diagonal(grid, row, col):
    # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la diagonal principal
    diagonal_values = [grid[i][i] for i in range(3)]
    return diagonal_values.count(9) <= 2 and grid[row][col] == 9 and 9 not in diagonal_values[:row] + diagonal_values[row + 1:]

def has_consecutive_in_inverse_diagonal(grid, row, col):
    # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la diagonal inversa
    inverse_diagonal_values = [grid[i][2 - i] for i in range(3)]
    
    '''
    print(inverse_diagonal_values)
    print("inverse_diagonal_values.count(9) <= 2\n",inverse_diagonal_values.count(9) <= 2)
    print("grid[row][col] == 9\n",grid[row][col] == 9)
    print("9 not in inverse_diagonal_values[:row] + inverse_diagonal_values[row + 1:]\n",9 not in inverse_diagonal_values[:row] + inverse_diagonal_values[row + 1:])
    print(inverse_diagonal_values[:row] + inverse_diagonal_values[row + 1:])
    '''
    
    return inverse_diagonal_values.count(9) <= 2 and grid[row][col] == 9 #and 9 not in inverse_diagonal_values[:row] + inverse_diagonal_values[row + 1:]


def has_consecutive(grid, row, col):
    # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la misma fila, columna, diagonal o diagonal inversa
    return (
        has_consecutive_in_row(grid, row, col) or
        has_consecutive_in_column(grid, row, col) or
        has_consecutive_in_main_diagonal(grid, row, col)or
        has_consecutive_in_inverse_diagonal(grid, row, col)
    )

# Ejemplo de uso:
grid = [
    [3, 2, 9],
    [9, 4, 9],
    [1, 6, 9],
]

#print(has_consecutive(grid, 2, 2))  # Debería retornar True

print(has_consecutive_in_column(grid, 0, 1))
print(has_consecutive_in_row(grid, 0, 2))
print(has_consecutive_in_main_diagonal(grid, 2, 2))
print(has_consecutive_in_inverse_diagonal(grid, 2, 2))

# %%
def has_consecutive_in_row(grid, row, col):
    # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la misma fila
    return grid[row].count(9) <= 2 and grid[row][col] == 9 and 9 not in grid[row][:col] + grid[row][col + 1:]

def has_consecutive_in_column(grid, row, col):
    # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la misma columna
    column_values = [grid[i][col] for i in range(3)]
    '''
    print(column_values)
    print("column_values.count(9) >= 2 \n", column_values.count(9) >= 2)
    print("grid[row][col] == 9 \n",grid[row][col] == 9)
    print("9 not in column_values[:row] + column_values[row + 1:]\n",9 not in column_values[:row] + column_values[row + 1:])
    '''
   
    return column_values.count(9) <= 2 and grid[row][col] == 9 and 9 not in column_values[:row] + column_values[row + 1:]

def has_consecutive_in_main_diagonal(grid, row, col):
    # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la diagonal principal
    diagonal_values = [grid[i][i] for i in range(3)]
    return diagonal_values.count(9) <= 2 and grid[row][col] == 9 and 9 not in diagonal_values[:row] + diagonal_values[row + 1:]

def has_consecutive_in_inverse_diagonal(grid, row, col):
    # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la diagonal inversa
    inverse_diagonal_values = [grid[i][2 - i] for i in range(3)]
    
    '''
    print(inverse_diagonal_values)
    print("inverse_diagonal_values.count(9) <= 2\n",inverse_diagonal_values.count(9) <= 2)
    print("grid[row][col] == 9\n",grid[row][col] == 9)
    print("9 not in inverse_diagonal_values[:row] + inverse_diagonal_values[row + 1:]\n",9 not in inverse_diagonal_values[:row] + inverse_diagonal_values[row + 1:])
    print(inverse_diagonal_values[:row] + inverse_diagonal_values[row + 1:])
    '''
    
    return inverse_diagonal_values.count(9) <= 2 and grid[row][col] == 9 #and 9 not in inverse_diagonal_values[:row] + inverse_diagonal_values[row + 1:]


def has_consecutive(grid, row, col):
    # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la misma fila, columna, diagonal o diagonal inversa
    return (
        has_consecutive_in_row(grid, row, col) or
        has_consecutive_in_column(grid, row, col) or
        has_consecutive_in_main_diagonal(grid, row, col)or
        has_consecutive_in_inverse_diagonal(grid, row, col)
    )

def is_valid(grid, num, row, col):
    # Verifica si el número ya está en la fila o columna
    for i in range(3):
        if grid[row][i] == num or grid[i][col] == num:
            return False

    # Verifica la suma de la diagonal principal
    if row == col and sum(grid[i][i] for i in range(3)) + num != 12:
        return False

    # Verifica la suma de la diagonal inversa
    if row + col == 2 and sum(grid[i][2 - i] for i in range(3)) + num != 12:
        return False

    return True

def solve(grid):
    empty = find_empty(grid)
    print("empty",empty)
    if not empty:
        return True  # Todas las celdas están llenas, el cuadrado está resuelto

    row, col = empty
    print(row,col)
    # Verifica si tiene dos casillas con valores diferentes a 9 en la misma fila, columna o diagonal
    if has_consecutive(grid, row, col):
        for num in range(0, 9):
            if is_valid(grid, num, row, col):
                grid[row][col] = num
                print(grid)
                if solve(grid):
                    return True  # Se encontró una solución

                grid[row][col] = 9  # Si no lleva a una solución, retrocede

    return False  # No hay solución con la configuración actual

def find_empty(grid):
    for i in range(3):
        for j in range(3):
            if grid[i][j] == 9:
                return (i, j)
    return None


grid = [
    [3, 9, 9],
    [9, 4, 9],
    [9, 6, 9],
]

'''
grid = [
    [3, 9, 9],
    [9, 4, 6],
    [9, 9, 9],
]
'''
    
def main():
   # Imprime el cuadrado mágico resuelto
    print("Matriz original:")
    for row in grid:
        print(row)

    if solve(grid):
        print("\nMatriz solucionada:")
        for row in grid:
            print(row)
    else:
        print("\nNo se pudo resolver la matriz.")    


if __name__ == "__main__":
    main()

# %%
grid = [
    [3, 2, 9],
    [9, 4, 9],
    [9, 6, 5],
]

def replace_9_with_0(grid):
    for i in range(len(grid)):
        for j in range(len(grid[i])):
            if grid[i][j] == 9:
                grid[i][j] = 0
    return grid


def check_row_and_column_sum(grid, row, col):
    row_sum = sum(grid[row])
    col_sum = sum([grid[i][col] for i in range(len(grid))])
    #print("row_sum",row_sum)
    #print("col_sum",col_sum)
    return row_sum == 12 or col_sum == 12


def check_sum(grid, row, col):
    grid=replace_9_with_0(grid)
    # Verifica que cumpla la suma = 12
    return check_row_and_column_sum(grid, row, col)

print(check_sum(grid, 0, 1))

# %%
def find_empty(grid):
    for i in range(3):
        for j in range(3):
            if grid[i][j] == 9:
                return (i, j)
    return None



def has_consecutive_in_row(grid, row, col):
    # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la misma fila
    return grid[row].count(9) <= 2 and grid[row][col] == 9 and 9 not in grid[row][:col] + grid[row][col + 1:]

def has_consecutive_in_column(grid, row, col):
    # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la misma columna
    column_values = [grid[i][col] for i in range(3)]
    '''
    print(column_values)
    print("column_values.count(9) >= 2 \n", column_values.count(9) >= 2)
    print("grid[row][col] == 9 \n",grid[row][col] == 9)
    print("9 not in column_values[:row] + column_values[row + 1:]\n",9 not in column_values[:row] + column_values[row + 1:])
    '''
   
    return column_values.count(9) <= 2 and grid[row][col] == 9 and 9 not in column_values[:row] + column_values[row + 1:]

def has_consecutive_in_main_diagonal(grid, row, col):
    # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la diagonal principal
    diagonal_values = [grid[i][i] for i in range(3)]
    return diagonal_values.count(9) <= 2 and grid[row][col] == 9 and 9 not in diagonal_values[:row] + diagonal_values[row + 1:]

def has_consecutive_in_inverse_diagonal(grid, row, col):
    # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la diagonal inversa
    inverse_diagonal_values = [grid[i][2 - i] for i in range(3)]
    
    '''
    print(inverse_diagonal_values)
    print("inverse_diagonal_values.count(9) <= 2\n",inverse_diagonal_values.count(9) <= 2)
    print("grid[row][col] == 9\n",grid[row][col] == 9)
    print("9 not in inverse_diagonal_values[:row] + inverse_diagonal_values[row + 1:]\n",9 not in inverse_diagonal_values[:row] + inverse_diagonal_values[row + 1:])
    print(inverse_diagonal_values[:row] + inverse_diagonal_values[row + 1:])
    '''
    
    return inverse_diagonal_values.count(9) <= 2 and grid[row][col] == 9 #and 9 not in inverse_diagonal_values[:row] + inverse_diagonal_values[row + 1:]


def has_consecutive(grid, row, col):
    # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la misma fila, columna, diagonal o diagonal inversa
    return (
        has_consecutive_in_row(grid, row, col) or
        has_consecutive_in_column(grid, row, col) or
        has_consecutive_in_main_diagonal(grid, row, col)or
        has_consecutive_in_inverse_diagonal(grid, row, col)
    )

def is_valid(grid, num, row, col):
    # Verifica si el número ya está en la fila o columna
    for i in range(3):
        if grid[row][i] == num or grid[i][col] == num:
            return False

    return True

def replace_9_with_any(matrix):
    for i in range(len(matrix)):
        for j in range(len(matrix[i])):
            if matrix[i][j] == 9:
                matrix[i][j] = 99
    return matrix
def replace_any_with_9(matrix):
    for i in range(len(matrix)):
        for j in range(len(matrix[i])):
            if matrix[i][j] == 99:
                matrix[i][j] = 9
    return matrix



def check_row_and_column_sum(matrix, row, col):
    row_sum = sum(matrix[row])
    col_sum = sum([matrix[i][col] for i in range(len(matrix))])
    #print("row_sum",row_sum)
    #print("col_sum",col_sum)
    print("** check sum: ",row_sum == 12 or col_sum == 12, "\n°°°°°°")
    return row_sum == 12 or col_sum == 12
'''
# Verifica la suma de la diagonal principal
    if row == col and sum(grid[i][i] for i in range(3)) + num != 12:
        return False

    # Verifica la suma de la diagonal inversa
    if row + col == 2 and sum(grid[i][2 - i] for i in range(3)) + num != 12:
        return False

'''

def check_sum(grid,num,row, col):
    grid[row][col]=num #asigna momentaneamente el valor 
    matrix=replace_9_with_any(grid)
    # Verifica que cumpla la suma = 12
    print("grid que llega a check sum")
    for r in matrix:
        print(r)
    return check_row_and_column_sum(matrix, row, col)


def solve(grid):
    
    empty = find_empty(grid)
    
    if not empty:
        return True  # Todas las celdas están llenas, el cuadrado está resuelto

    row, col = empty
    print("_______________________________________________________")
    print("casilla vacia:",row,col,"\n_______________________________________________________")
    # Verifica si tiene dos casillas con valores diferentes a 9 en la misma fila, columna o diagonal
    print("has_consecutive:",has_consecutive(grid, row, col),"\n%%%%%%%%%%%%%%%%%%%%%%")
    if has_consecutive(grid, row, col):
        for num in range(0, 9):
            print("num:",num)
            print("is valid:",is_valid(grid, num, row, col))
            if is_valid(grid, num, row, col):
                
                
                if check_sum(grid,num, row, col):
                    grid[row][col] = num
                    replace_any_with_9(grid)
                                  
                    print("llamada recursiva al backtracking con grid: \n")
                    for r in grid:
                        print(r)
                    print()
                    if solve(grid):
                        print("entra al true final")
                        return True  # Se encontró una solución
                    print("retrocede")
                    replace_any_with_9(grid)
                    grid[row][col] = 9  # Si no lleva a una solución, retrocede

    return False  # No hay solución con la configuración actual




grid = [
    [3, 9, 9],
    [9, 4, 9],
    [9, 6, 5],
]

'''
grid = [
    [3, 2, 7],
    [8, 4, 0],
    [1, 6, 5],
]
'''   
def main():
   # Imprime el cuadrado mágico resuelto
    print("Matriz original:")
    for row in grid:
        print(row)

    if solve(grid):
        print("\nMatriz solucionada:")
        for row in grid:
            print(row)
    else:
        print("\nNo se pudo resolver la matriz.")    


if __name__ == "__main__":
    main()

# %% [markdown]
# # v2

# %%
def find_empty(grid):
    for i in range(3):
        for j in range(3):
            if grid[i][j] == 9:
                return (i, j)
    return None



def has_consecutive_in_row(grid, row, col):
    # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la misma fila
    return grid[row].count(9) <= 2 and grid[row][col] == 9 and 9 not in grid[row][:col] + grid[row][col + 1:]

def has_consecutive_in_column(grid, row, col):
    # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la misma columna
    column_values = [grid[i][col] for i in range(3)]
    '''
    print(column_values)
    print("column_values.count(9) >= 2 \n", column_values.count(9) >= 2)
    print("grid[row][col] == 9 \n",grid[row][col] == 9)
    print("9 not in column_values[:row] + column_values[row + 1:]\n",9 not in column_values[:row] + column_values[row + 1:])
    '''
   
    return column_values.count(9) <= 2 and grid[row][col] == 9 and 9 not in column_values[:row] + column_values[row + 1:]

def has_consecutive_in_main_diagonal(grid, row, col):
    # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la diagonal principal
    diagonal_values = [grid[i][i] for i in range(3)]
    return diagonal_values.count(9) <= 2 and grid[row][col] == 9 and 9 not in diagonal_values[:row] + diagonal_values[row + 1:]

def has_consecutive_in_inverse_diagonal(grid, row, col):
    # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la diagonal inversa
    inverse_diagonal_values = [grid[i][2 - i] for i in range(3)]
    
    '''
    print(inverse_diagonal_values)
    print("inverse_diagonal_values.count(9) <= 2\n",inverse_diagonal_values.count(9) <= 2)
    print("grid[row][col] == 9\n",grid[row][col] == 9)
    print("9 not in inverse_diagonal_values[:row] + inverse_diagonal_values[row + 1:]\n",9 not in inverse_diagonal_values[:row] + inverse_diagonal_values[row + 1:])
    print(inverse_diagonal_values[:row] + inverse_diagonal_values[row + 1:])
    '''
    
    return inverse_diagonal_values.count(9) <= 2 and grid[row][col] == 9 #and 9 not in inverse_diagonal_values[:row] + inverse_diagonal_values[row + 1:]


def has_consecutive(grid, row, col):
    # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la misma fila, columna, diagonal o diagonal inversa
    return (
        has_consecutive_in_row(grid, row, col) or
        has_consecutive_in_column(grid, row, col) or
        has_consecutive_in_main_diagonal(grid, row, col)or
        has_consecutive_in_inverse_diagonal(grid, row, col)
    )

def is_valid(grid, num, row, col):
    # Verifica si el número ya está en la fila o columna
    for i in range(3):
        if grid[row][i] == num or grid[i][col] == num:
            return False

    return True

def replace_9_with_any(matrix):
    for i in range(len(matrix)):
        for j in range(len(matrix[i])):
            if matrix[i][j] == 9:
                matrix[i][j] = 99
    return matrix
def replace_any_with_9(matrix):
    for i in range(len(matrix)):
        for j in range(len(matrix[i])):
            if matrix[i][j] == 99:
                matrix[i][j] = 9
    return matrix



def check_row_and_column_sum(matrix, row, col):
    row_sum = sum(matrix[row])
    col_sum = sum([matrix[i][col] for i in range(len(matrix))])
    #print("row_sum",row_sum)
    #print("col_sum",col_sum)
    print("** check sum: ",row_sum == 12 or col_sum == 12, "\n°°°°°°")
    return row_sum == 12 or col_sum == 12

def check_diagonals(matrix, row, col):
    if row==col or row-2==col or col-2==row:
        diagonal1 = sum(matrix[i][i] for i in range(len(matrix)))
        diagonal2 = sum(matrix[i][len(matrix) - 1 - i] for i in range(len(matrix)))
        # Verifica la suma de la diagonal principal y diagonal inversa
        return diagonal1 == 12 or diagonal2 == 12
    else:
        return False

    

def check_sum(grid,num,row, col):
    grid[row][col]=num #asigna momentaneamente el valor 
    matrix=replace_9_with_any(grid)
    # Verifica que cumpla la suma = 12
    print("grid que llega a check sum")
    for r in matrix:
        print(r)
    return check_row_and_column_sum(matrix, row, col) # or check_diagonals(matrix, row, col)


def solve(grid):
    
    empty = find_empty(grid)
    
    if not empty:
        return True  # Todas las celdas están llenas, el cuadrado está resuelto

    row, col = empty
    print("_______________________________________________________")
    print("casilla vacia:",row,col,"\n_______________________________________________________")
    # Verifica si tiene dos casillas con valores diferentes a 9 en la misma fila, columna o diagonal
    print("has_consecutive:",has_consecutive(grid, row, col),"\n%%%%%%%%%%%%%%%%%%%%%%")
    if has_consecutive(grid, row, col):
        for num in range(0, 9):
            print("num:",num)
            print("is valid:",is_valid(grid, num, row, col))
            if is_valid(grid, num, row, col):
                
                
                if check_sum(grid,num, row, col):
                    grid[row][col] = num
                    replace_any_with_9(grid)
                                  
                    print("llamada recursiva al backtracking con grid: \n")
                    for r in grid:
                        print(r)
                    print()
                    if solve(grid):
                        print("entra al true final")
                        return True  # Se encontró una solución
                    #'''
                    print("retrocede")
                    replace_any_with_9(grid)
                    print("grid despues de salir de backtracking")
                    for r in grid:
                        print(r)
                    #'''    
                    grid[row][col] = 9  # Si no lleva a una solución, retrocede

    return False  # No hay solución con la configuración actual

grid = [
    [3, 9, 9],
    [9, 4, 9],
    [9, 6, 5],
]

'''
grid = [
    [3, 2, 7],
    [8, 4, 0],
    [1, 6, 5],
]
'''   
def main():
   # Imprime el cuadrado mágico resuelto
    print("Matriz original:")
    for row in grid:
        print(row)

    if solve(grid):
        print("\nMatriz solucionada:")
        for row in grid:
            print(row)
    else:
        print("\nNo se pudo resolver la matriz.")    

if __name__ == "__main__":
    main()

# %%
def has_consecutive_in_row(grid, row, col):
    # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la misma fila
    return grid[row].count(9) <= 2 and grid[row][col] == 9 and 9 not in grid[row][:col] + grid[row][col + 1:]

def has_consecutive_in_column(grid, row, col):
    # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la misma columna
    column_values = [grid[i][col] for i in range(3)]
    return column_values.count(9) <= 2 and grid[row][col] == 9 and 9 not in column_values[:row] + column_values[row + 1:]

def has_consecutive_in_main_diagonal(grid, row, col):
    if row==col or row-2==col or col-2==row:
        # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la diagonal principal
        diagonal_values = [grid[i][i] for i in range(3)]
        return diagonal_values.count(9) <= 2 and grid[row][col] == 9 and 9 not in diagonal_values[:row] + diagonal_values[row + 1:]
    else: 
        return False
def has_consecutive_in_inverse_diagonal(grid, row, col):
    if row==col or row-2==col or col-2==row:
        # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la diagonal inversa
        inverse_diagonal_values = [grid[i][2 - i] for i in range(3)]
        return inverse_diagonal_values.count(9) <= 2 and grid[row][col] == 9 #and 9 not in inverse_diagonal_values[:row] + inverse_diagonal_values[row + 1:]
    else: 
        return False

def has_consecutive(grid, row, col):
    # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la misma fila, columna, diagonal o diagonal inversa
    return (
        has_consecutive_in_row(grid, row, col) or
        has_consecutive_in_column(grid, row, col) or
        has_consecutive_in_main_diagonal(grid, row, col)or
        has_consecutive_in_inverse_diagonal(grid, row, col)
    )

grid=[
    [3, 2, 7],
    [9, 4, 9],
    [9, 6, 5],
]
print("T",has_consecutive(grid, 1, 0))
print("row",has_consecutive_in_row(grid, 1, 0))
print("col",has_consecutive_in_column(grid, 1, 0))
print("main",has_consecutive_in_main_diagonal(grid, 1, 0))
print("inv",has_consecutive_in_inverse_diagonal(grid, 1, 0))

# %% [markdown]
# # v3
# la version 4, 5 y 6 son para intentar solucionar el error del has consecutive, mejor hasta ahora

# %%
def find_empty(grid):
    for i in range(3):
        for j in range(3):
            if grid[i][j] == 9:
                return (i, j)
                
    return None

def has_consecutive_in_row(grid, row, col):
    # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la misma fila
    return grid[row].count(9) <= 2 and grid[row][col] == 9 and 9 not in grid[row][:col] + grid[row][col + 1:]

def has_consecutive_in_column(grid, row, col):
    # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la misma columna
    column_values = [grid[i][col] for i in range(3)]
    return column_values.count(9) <= 2 and grid[row][col] == 9 and 9 not in column_values[:row] + column_values[row + 1:]

def has_consecutive_in_main_diagonal(grid, row, col):
    if row==col or row-2==col or col-2==row:
        # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la diagonal principal
        diagonal_values = [grid[i][i] for i in range(3)]
        return diagonal_values.count(9) <= 2 and grid[row][col] == 9 and 9 not in diagonal_values[:row] + diagonal_values[row + 1:]
    else: 
        return False
def has_consecutive_in_inverse_diagonal(grid, row, col):
    if row==col or row-2==col or col-2==row:
        # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la diagonal inversa
        inverse_diagonal_values = [grid[i][2 - i] for i in range(3)]
        return inverse_diagonal_values.count(9) <= 2 and grid[row][col] == 9 #and 9 not in inverse_diagonal_values[:row] + inverse_diagonal_values[row + 1:]
    else: 
        return False

def has_consecutive(grid, row, col):
    # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la misma fila, columna, diagonal o diagonal inversa
    return (
        has_consecutive_in_row(grid, row, col) or
        has_consecutive_in_column(grid, row, col) or
        has_consecutive_in_main_diagonal(grid, row, col)or
        has_consecutive_in_inverse_diagonal(grid, row, col)
    )

def is_valid(grid, num, row, col):
    # Verifica si el número ya está en la fila o columna
    for i in range(3):
        if grid[row][i] == num or grid[i][col] == num:
            return False

    return True

def replace_9_with_any(matrix):
    for i in range(len(matrix)):
        for j in range(len(matrix[i])):
            if matrix[i][j] == 9:
                matrix[i][j] = 99
    return matrix
def replace_any_with_9(matrix):
    for i in range(len(matrix)):
        for j in range(len(matrix[i])):
            if matrix[i][j] == 99:
                matrix[i][j] = 9
    return matrix

def check_row_and_column_sum(matrix, row, col):
    row_sum = sum(matrix[row])
    col_sum = sum([matrix[i][col] for i in range(len(matrix))])
    #print("row_sum",row_sum)
    #print("col_sum",col_sum)
    print("** check sum: ",row_sum == 12 or col_sum == 12, "\n°°°°°°")
    return row_sum == 12 or col_sum == 12

def check_diagonals(matrix, row, col):
    if row==col or row-2==col or col-2==row:
        diagonal1 = sum(matrix[i][i] for i in range(len(matrix)))
        diagonal2 = sum(matrix[i][len(matrix) - 1 - i] for i in range(len(matrix)))
        # Verifica la suma de la diagonal principal y diagonal inversa
        return diagonal1 == 12 or diagonal2 == 12
    else:
        return False

    

def check_sum(grid,num,row, col):
    grid[row][col]=num #asigna momentaneamente el valor 
    matrix=replace_9_with_any(grid)
    # Verifica que cumpla la suma = 12
    print("grid que llega a check sum")
    for r in matrix:
        print(r)
    return check_row_and_column_sum(matrix, row, col) # or check_diagonals(matrix, row, col)


def solve(grid):
    
    empty = find_empty(grid)
    
    if not empty:
        return True  # Todas las celdas están llenas, el cuadrado está resuelto

    row, col = empty
    print("_______________________________________________________")
    print("casilla vacia:",row,col,"\n_______________________________________________________")
    # Verifica si tiene dos casillas con valores diferentes a 9 en la misma fila, columna o diagonal
    print("has_consecutive:",has_consecutive(grid, row, col),"\n%%%%%%%%%%%%%%%%%%%%%%")
    if has_consecutive(grid, row, col):
        for num in range(0, 9):
            print("num:",num)
            print("is valid:",is_valid(grid, num, row, col))
            if is_valid(grid, num, row, col):
                
                
                if check_sum(grid,num, row, col):
                    grid[row][col] = num
                    replace_any_with_9(grid)
                                  
                    print("llamada recursiva al backtracking con grid: \n")
                    for r in grid:
                        print(r)
                    print()
                    if solve(grid):
                        print("entra al true final")
                        return True  # Se encontró una solución
                    #'''
                    
                    print("retrocede")
                    replace_any_with_9(grid)
                    
                    print("grid despues de salir de backtracking")
                    for r in grid:
                        print(r)
                    #'''    
                    grid[row][col] = 9  # Si no lleva a una solución, retrocede
    
    
    
    return False  # No hay solución con la configuración actual

grid = [
    [3, 9, 9],
    [9, 4, 9],
    [9, 6, 5],
]

'''
grid = [
    [3, 2, 7],
    [8, 4, 0],
    [1, 6, 5],
]
'''   
def main():
   # Imprime el cuadrado mágico resuelto
    print("Matriz original:")
    for row in grid:
        print(row)

    if solve(grid):
        print("\nMatriz solucionada:")
        for row in grid:
            print(row)
    else:
        print("\nNo se pudo resolver la matriz.")    

if __name__ == "__main__":
    main()

# %% [markdown]
# # v4

# %%
def find_empty(grid):
    for i in range(3):
        for j in range(3):
            if grid[i][j] == 9:
                return (i, j)
    return None

def has_consecutive_in_row(grid, row, col):
    # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la misma fila
    return grid[row].count(9) <= 2 and grid[row][col] == 9 and 9 not in grid[row][:col] + grid[row][col + 1:]

def has_consecutive_in_column(grid, row, col):
    # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la misma columna
    column_values = [grid[i][col] for i in range(3)]
    return column_values.count(9) <= 2 and grid[row][col] == 9 and 9 not in column_values[:row] + column_values[row + 1:]

def has_consecutive_in_main_diagonal(grid, row, col):
    if row==col or row-2==col or col-2==row:
        # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la diagonal principal
        diagonal_values = [grid[i][i] for i in range(3)]
        return diagonal_values.count(9) <= 2 and grid[row][col] == 9 and 9 not in diagonal_values[:row] + diagonal_values[row + 1:]
    else: 
        return False
def has_consecutive_in_inverse_diagonal(grid, row, col):
    if row==col or row-2==col or col-2==row:
        # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la diagonal inversa
        inverse_diagonal_values = [grid[i][2 - i] for i in range(3)]
        return inverse_diagonal_values.count(9) <= 2 and grid[row][col] == 9 #and 9 not in inverse_diagonal_values[:row] + inverse_diagonal_values[row + 1:]
    else: 
        return False

def has_consecutive(grid, row, col):
    # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la misma fila, columna, diagonal o diagonal inversa
    return (
        has_consecutive_in_row(grid, row, col) or
        has_consecutive_in_column(grid, row, col) or
        has_consecutive_in_main_diagonal(grid, row, col)or
        has_consecutive_in_inverse_diagonal(grid, row, col)
    )

def is_valid(grid, num, row, col):
    # Verifica si el número ya está en la fila o columna
    for i in range(3):
        if grid[row][i] == num or grid[i][col] == num:
            return False

    return True

def replace_9_with_any(matrix):
    for i in range(len(matrix)):
        for j in range(len(matrix[i])):
            if matrix[i][j] == 9:
                matrix[i][j] = 99
    return matrix
def replace_any_with_9(matrix):
    for i in range(len(matrix)):
        for j in range(len(matrix[i])):
            if matrix[i][j] == 99:
                matrix[i][j] = 9
    return matrix

def check_row_and_column_sum(matrix, row, col):
    row_sum = sum(matrix[row])
    col_sum = sum([matrix[i][col] for i in range(len(matrix))])
    #print("row_sum",row_sum)
    #print("col_sum",col_sum)
    print("** check sum: ",row_sum == 12 or col_sum == 12, "\n°°°°°°")
    return row_sum == 12 or col_sum == 12

def check_diagonals(matrix, row, col):
    if row==col or row-2==col or col-2==row:
        diagonal1 = sum(matrix[i][i] for i in range(len(matrix)))
        diagonal2 = sum(matrix[i][len(matrix) - 1 - i] for i in range(len(matrix)))
        # Verifica la suma de la diagonal principal y diagonal inversa
        return diagonal1 == 12 or diagonal2 == 12
    else:
        return False

    

def check_sum(grid,num,row, col):
    grid[row][col]=num #asigna momentaneamente el valor 
    matrix=replace_9_with_any(grid)
    # Verifica que cumpla la suma = 12
    print("grid que llega a check sum")
    for r in matrix:
        print(r)
    return check_row_and_column_sum(matrix, row, col) # or check_diagonals(matrix, row, col)

def transpose_matrix(matrix):
    # Initialize an empty matrix of the same size
    transposed_matrix = [[0 for _ in range(len(matrix))] for _ in range(len(matrix[0]))]
    
    # Fill in the transposed matrix
    for i in range(len(matrix)):
        for j in range(len(matrix[i])):
            transposed_matrix[j][i] = matrix[i][j]
            
    return transposed_matrix


def solve(grid):
    
    empty = find_empty(grid)
    
    if not empty:
        return True  # Todas las celdas están llenas, el cuadrado está resuelto

    row, col = empty
    print("_______________________________________________________")
    print("casilla vacia:",row,col,"\n_______________________________________________________")
    # Verifica si tiene dos casillas con valores diferentes a 9 en la misma fila, columna o diagonal
    print("has_consecutive:",has_consecutive(grid, row, col),"\n%%%%%%%%%%%%%%%%%%%%%%")
    
    for num in range(0, 9):
        print("num:",num)
        print("is valid:",is_valid(grid, num, row, col))
        if is_valid(grid, num, row, col):
            if has_consecutive(grid, row, col):
                if check_sum(grid,num, row, col):
                    grid[row][col] = num
                    replace_any_with_9(grid)

                    print("llamada recursiva al backtracking con grid: \n")
                    for r in grid:
                        print(r)
                    print()
                    if solve(grid):
                        print("entra al true final")
                        return True  # Se encontró una solución
                    #'''

                    print("retrocede")
                    replace_any_with_9(grid)

                    print("grid despues de salir de backtracking")
                    for r in grid:
                        print(r)
                     #'''    
                    grid[row][col] = 9  # Si no lleva a una solución, retrocede
            else:
                t_grid=transpose_matrix(grid)
                if solve(t_grid):
                    print("entra al true final")
                    return True  # Se encontró una solución
                
  
    return False  # No hay solución con la configuración actual

grid = [
    [3, 9, 9],
    [9, 4, 9],
    [9, 6, 5],
]

'''
grid = [
    [3, 2, 7],
    [8, 4, 0],
    [1, 6, 5],
]
'''   
def main():
   # Imprime el cuadrado mágico resuelto
    print("Matriz original:")
    for row in grid:
        print(row)

    if solve(grid):
        print("\nMatriz solucionada:")
        for row in grid:
            print(row)
    else:
        print("\nNo se pudo resolver la matriz.")    

if __name__ == "__main__":
    main()

# %%
def transpose_matrix(matrix):
    # Initialize an empty matrix of the same size
    transposed_matrix = [[0 for _ in range(len(matrix))] for _ in range(len(matrix[0]))]
    
    # Fill in the transposed matrix
    for i in range(len(matrix)):
        for j in range(len(matrix[i])):
            transposed_matrix[j][i] = matrix[i][j]
            
    return transposed_matrix

else:
    t_grid=transpose_matrix(grid)
    if solve(t_grid):
        print("entra al true final")
        return True  # Se encontró una solución

# %% [markdown]
# # v5

# %%
def find_empty(grid):
    for i in range(3):
        for j in range(3):
            if grid[i][j] == 9:
                return (i, j)
    return None

def has_consecutive_in_row(grid, row, col):
    # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la misma fila
    return grid[row].count(9) <= 2 and grid[row][col] == 9 and 9 not in grid[row][:col] + grid[row][col + 1:]

def has_consecutive_in_column(grid, row, col):
    # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la misma columna
    column_values = [grid[i][col] for i in range(3)]
    return column_values.count(9) <= 2 and grid[row][col] == 9 and 9 not in column_values[:row] + column_values[row + 1:]

def has_consecutive_in_main_diagonal(grid, row, col):
    if row==col or row-2==col or col-2==row:
        # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la diagonal principal
        diagonal_values = [grid[i][i] for i in range(3)]
        return diagonal_values.count(9) <= 2 and grid[row][col] == 9 and 9 not in diagonal_values[:row] + diagonal_values[row + 1:]
    else: 
        return False
def has_consecutive_in_inverse_diagonal(grid, row, col):
    if row==col or row-2==col or col-2==row:
        # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la diagonal inversa
        inverse_diagonal_values = [grid[i][2 - i] for i in range(3)]
        return inverse_diagonal_values.count(9) <= 2 and grid[row][col] == 9 #and 9 not in inverse_diagonal_values[:row] + inverse_diagonal_values[row + 1:]
    else: 
        return False

def has_consecutive(grid, row, col):
    # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la misma fila, columna, diagonal o diagonal inversa
    return (
        has_consecutive_in_row(grid, row, col) or
        has_consecutive_in_column(grid, row, col) or
        has_consecutive_in_main_diagonal(grid, row, col)or
        has_consecutive_in_inverse_diagonal(grid, row, col)
    )

def transpose_matrix(matrix):
    # Initialize an empty matrix of the same size
    transposed_matrix = [[0 for _ in range(len(matrix))] for _ in range(len(matrix[0]))]
    
    # Fill in the transposed matrix
    for i in range(len(matrix)):
        for j in range(len(matrix[i])):
            transposed_matrix[j][i] = matrix[i][j]
            
    return transposed_matrix


def is_valid(grid, num, row, col):
    # Verifica si el número ya está en la fila o columna
    for i in range(3):
        if grid[row][i] == num or grid[i][col] == num:
            return False

    return True

def replace_9_with_any(matrix):
    for i in range(len(matrix)):
        for j in range(len(matrix[i])):
            if matrix[i][j] == 9:
                matrix[i][j] = 99
    return matrix
def replace_any_with_9(matrix):
    for i in range(len(matrix)):
        for j in range(len(matrix[i])):
            if matrix[i][j] == 99:
                matrix[i][j] = 9
    return matrix

def check_row_and_column_sum(matrix, row, col):
    row_sum = sum(matrix[row])
    col_sum = sum([matrix[i][col] for i in range(len(matrix))])
    #print("row_sum",row_sum)
    #print("col_sum",col_sum)
    print("** check sum: ",row_sum == 12 or col_sum == 12, "\n°°°°°°")
    return row_sum == 12 or col_sum == 12

def check_diagonals(matrix, row, col):
    if row==col or row-2==col or col-2==row:
        diagonal1 = sum(matrix[i][i] for i in range(len(matrix)))
        diagonal2 = sum(matrix[i][len(matrix) - 1 - i] for i in range(len(matrix)))
        # Verifica la suma de la diagonal principal y diagonal inversa
        return diagonal1 == 12 or diagonal2 == 12
    else:
        return False

    

def check_sum(grid,num,row, col):
    grid[row][col]=num #asigna momentaneamente el valor 
    matrix=replace_9_with_any(grid)
    # Verifica que cumpla la suma = 12
    print("grid que llega a check sum")
    for r in matrix:
        print(r)
    return check_row_and_column_sum(matrix, row, col) # or check_diagonals(matrix, row, col)


def solve(grid):
    
    empty = find_empty(grid)
    
    if not empty:
        return True  # Todas las celdas están llenas, el cuadrado está resuelto

    row, col = empty
    print("_______________________________________________________")
    print("casilla vacia:",row,col,"\n_______________________________________________________")
    # Verifica si tiene dos casillas con valores diferentes a 9 en la misma fila, columna o diagonal
    print("has_consecutive:",has_consecutive(grid, row, col),"\n%%%%%%%%%%%%%%%%%%%%%%")
    if has_consecutive(grid, row, col):
        for num in range(0, 9):
            print("num:",num)
            print("is valid:",is_valid(grid, num, row, col))
            if is_valid(grid, num, row, col):
                
                
                if check_sum(grid,num, row, col):
                    grid[row][col] = num
                    replace_any_with_9(grid)
                                  
                    print("llamada recursiva al backtracking con grid: \n")
                    for r in grid:
                        print(r)
                    print()
                    if solve(grid):
                        print("entra al true final")
                        return True  # Se encontró una solución
                    #'''
                    
                    print("retrocede")
                    replace_any_with_9(grid)
                    
                    print("grid despues de salir de backtracking")
                    for r in grid:
                        print(r)
                    #'''    
                    grid[row][col] = 9  # Si no lleva a una solución, retrocede
    
    else:
        t_grid=transpose_matrix(grid)
        if solve(t_grid):
            print("entra al true final")
            return True  # Se encontró una solución
    
    return False  # No hay solución con la configuración actual

grid = [
    [3, 9, 9],
    [9, 4, 9],
    [9, 6, 5],
]

'''
grid = [
    [3, 2, 7],
    [8, 4, 0],
    [1, 6, 5],
]
'''   
def main():
   # Imprime el cuadrado mágico resuelto
    print("Matriz original:")
    for row in grid:
        print(row)

    if solve(grid):
        print("\nMatriz solucionada:")
        for row in grid:
            print(row)
    else:
        print("\nNo se pudo resolver la matriz.")    

if __name__ == "__main__":
    main()

# %% [markdown]
# # v6 funcional para P01

# %%
def find_empty(grid):
    for i in range(3):
        for j in range(3):
            if grid[i][j] == 9:
                if has_consecutive(grid, i, j):
                    print(f"¬¬¬¬¬¬¬¬¬¬¬¬¬¬¬¬¬¬¬¬coordenadas: {i},{j}¬¬¬¬¬¬¬¬¬¬¬¬¬¬¬¬¬¬¬¬¬¬" )
                    return (i, j)
                    
                else:
                    j+1
    return None

def has_consecutive_in_row(grid, row, col):
    # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la misma fila
    return grid[row].count(9) <= 2 and grid[row][col] == 9 and 9 not in grid[row][:col] + grid[row][col + 1:]

def has_consecutive_in_column(grid, row, col):
    # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la misma columna
    column_values = [grid[i][col] for i in range(3)]
    return column_values.count(9) <= 2 and grid[row][col] == 9 and 9 not in column_values[:row] + column_values[row + 1:]

def has_consecutive_in_main_diagonal(grid, row, col):
    if row==col or row-2==col or col-2==row:
        # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la diagonal principal
        diagonal_values = [grid[i][i] for i in range(3)]
        return diagonal_values.count(9) <= 2 and grid[row][col] == 9 and 9 not in diagonal_values[:row] + diagonal_values[row + 1:]
    else: 
        return False
def has_consecutive_in_inverse_diagonal(grid, row, col):
    if row==col or row-2==col or col-2==row:
        # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la diagonal inversa
        inverse_diagonal_values = [grid[i][2 - i] for i in range(3)]
        return inverse_diagonal_values.count(9) <= 2 and grid[row][col] == 9 #and 9 not in inverse_diagonal_values[:row] + inverse_diagonal_values[row + 1:]
    else: 
        return False

def has_consecutive(grid, row, col):
    # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la misma fila, columna, diagonal o diagonal inversa
    return (
        has_consecutive_in_row(grid, row, col) or
        has_consecutive_in_column(grid, row, col) or
        has_consecutive_in_main_diagonal(grid, row, col)or
        has_consecutive_in_inverse_diagonal(grid, row, col)
    )

def is_valid(grid, num, row, col):
    # Verifica si el número ya está en la fila o columna
    for i in range(3):
        if grid[row][i] == num or grid[i][col] == num:
            return False

    return True

def replace_9_with_any(matrix):
    for i in range(len(matrix)):
        for j in range(len(matrix[i])):
            if matrix[i][j] == 9:
                matrix[i][j] = 99
    return matrix
def replace_any_with_9(matrix):
    for i in range(len(matrix)):
        for j in range(len(matrix[i])):
            if matrix[i][j] == 99:
                matrix[i][j] = 9
    return matrix

def check_row_and_column_sum(matrix, row, col):
    row_sum = sum(matrix[row])
    col_sum = sum([matrix[i][col] for i in range(len(matrix))])
    #print("row_sum",row_sum)
    #print("col_sum",col_sum)
    print("** check sum: ",row_sum == 12 or col_sum == 12, "\n°°°°°°")
    return row_sum == 12 or col_sum == 12

def check_diagonals(matrix, row, col):
    if row==col or row-2==col or col-2==row:
        diagonal1 = sum(matrix[i][i] for i in range(len(matrix)))
        diagonal2 = sum(matrix[i][len(matrix) - 1 - i] for i in range(len(matrix)))
        # Verifica la suma de la diagonal principal y diagonal inversa
        return diagonal1 == 12 or diagonal2 == 12
    else:
        return False

    

def check_sum(grid,num,row, col):
    grid[row][col]=num #asigna momentaneamente el valor 
    matrix=replace_9_with_any(grid)
    # Verifica que cumpla la suma = 12
    print("grid que llega a check sum")
    for r in matrix:
        print(r)
    return check_row_and_column_sum(matrix, row, col) # or check_diagonals(matrix, row, col)


def solve(grid):
    
    empty = find_empty(grid)
    
    if not empty:
        return True  # Todas las celdas están llenas, el cuadrado está resuelto

    row, col = empty
    print("_______________________________________________________")
    print("casilla vacia:",row,col,"\n_______________________________________________________")
    # Verifica si tiene dos casillas con valores diferentes a 9 en la misma fila, columna o diagonal
    print("has_consecutive:",has_consecutive(grid, row, col),"\n%%%%%%%%%%%%%%%%%%%%%%")
    if has_consecutive(grid, row, col):
        for num in range(0, 9):
            print("num:",num)
            print("is valid:",is_valid(grid, num, row, col))
            if is_valid(grid, num, row, col):
                
                
                if check_sum(grid,num, row, col):
                    grid[row][col] = num
                    replace_any_with_9(grid)
                                  
                    print("llamada recursiva al backtracking con grid: \n")
                    for r in grid:
                        print(r)
                    print()
                    if solve(grid):
                        print("entra al true final")
                        return True  # Se encontró una solución
                    #'''
                    
                    print("retrocede")
                    replace_any_with_9(grid)
                    
                    print("grid despues de salir de backtracking")
                    for r in grid:
                        print(r)
                    #'''    
                    grid[row][col] = 9  # Si no lleva a una solución, retrocede
    
    
    
    return False  # No hay solución con la configuración actual

grid = [
    [3, 9, 9],
    [9, 4, 9],
    [9, 6, 5],
]

'''
grid = [
    [3, 2, 7],
    [8, 4, 0],
    [1, 6, 5],
]
'''   
def main():
   # Imprime el cuadrado mágico resuelto
    print("Matriz original:")
    for row in grid:
        print(row)

    if solve(grid):
        print("\nMatriz solucionada:")
        for row in grid:
            print(row)
    else:
        print("\nNo se pudo resolver la matriz.")    

if __name__ == "__main__":
    main()

# %% [markdown]
# # v7

# %%
def find_empty(grid):
    for i in range(3):
        for j in range(3):
            if grid[i][j] == 9:
                if has_consecutive(grid, i, j): # halla si en esa fila o columna existen 2 caasillas != 9
                    print(f"¬¬¬¬¬¬¬¬¬¬¬¬¬¬¬¬¬¬¬¬coordenadas: {i},{j}¬¬¬¬¬¬¬¬¬¬¬¬¬¬¬¬¬¬¬¬¬¬" )
                    return (i, j)
                    
                else:
                    j+1
    return None

def has_consecutive_in_row(grid, row, col):
    # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la misma fila
    return grid[row].count(9) <= 2 and grid[row][col] == 9 and 9 not in grid[row][:col] + grid[row][col + 1:]

def has_consecutive_in_column(grid, row, col):
    # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la misma columna
    column_values = [grid[i][col] for i in range(3)]
    return column_values.count(9) <= 2 and grid[row][col] == 9 and 9 not in column_values[:row] + column_values[row + 1:]

def has_consecutive_in_main_diagonal(grid, row, col):
    if row==col or row-2==col or col-2==row:
        # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la diagonal principal
        diagonal_values = [grid[i][i] for i in range(3)]
        return diagonal_values.count(9) <= 2 and grid[row][col] == 9 and 9 not in diagonal_values[:row] + diagonal_values[row + 1:]
    else: 
        return False
def has_consecutive_in_inverse_diagonal(grid, row, col):
    if row==col or row-2==col or col-2==row:
        # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la diagonal inversa
        inverse_diagonal_values = [grid[i][2 - i] for i in range(3)]
        return inverse_diagonal_values.count(9) <= 2 and grid[row][col] == 9 #and 9 not in inverse_diagonal_values[:row] + inverse_diagonal_values[row + 1:]
    else: 
        return False

def has_consecutive(grid, row, col):
    # Verifica si tiene dos casillas consecutivas con valores diferentes a 9 en la misma fila, columna, diagonal o diagonal inversa
    return (
        has_consecutive_in_row(grid, row, col) or
        has_consecutive_in_column(grid, row, col) or
        has_consecutive_in_main_diagonal(grid, row, col)or
        has_consecutive_in_inverse_diagonal(grid, row, col)
    )

def is_valid(grid, num, row, col):
    # Verifica si el número ya está en la fila o columna
    for i in range(3):
        if grid[row][i] == num or grid[i][col] == num:
            return False

    return True

def replace_9_with_any(matrix):
    for i in range(len(matrix)):
        for j in range(len(matrix[i])):
            if matrix[i][j] == 9:
                matrix[i][j] = 99
    return matrix
def replace_any_with_9(matrix):
    for i in range(len(matrix)):
        for j in range(len(matrix[i])):
            if matrix[i][j] == 99:
                matrix[i][j] = 9
    return matrix

def check_row_and_column_sum(matrix, row, col):
    row_sum = sum(matrix[row])
    col_sum = sum([matrix[i][col] for i in range(len(matrix))])
    #print("row_sum",row_sum)
    #print("col_sum",col_sum)
    print("** check sum: ",row_sum == 12 or col_sum == 12, "\n°°°°°°")
    return row_sum == 12 or col_sum == 12

def check_diagonals(matrix, row, col):
    if row==col or row-2==col or col-2==row:
        diagonal1 = sum(matrix[i][i] for i in range(len(matrix)))
        diagonal2 = sum(matrix[i][len(matrix) - 1 - i] for i in range(len(matrix)))
        # Verifica la suma de la diagonal principal y diagonal inversa
        return diagonal1 == 12 or diagonal2 == 12
    else:
        return False

    

def check_sum(grid,num,row, col):
    grid[row][col]=num #asigna momentaneamente el valor 
    matrix=replace_9_with_any(grid)
    # Verifica que cumpla la suma = 12
    print("grid que llega a check sum")
    for r in matrix:
        print(r)
    return check_row_and_column_sum(matrix, row, col) # or check_diagonals(matrix, row, col)


def solve(grid):
    
    empty = find_empty(grid) # halla las coordenadas de las casillas vacias
    
    if not empty:
        return True  # Todas las celdas están llenas, el cuadrado está resuelto

    row, col = empty
    print("_______________________________________________________")
    print("casilla vacia:",row,col,"\n_______________________________________________________")
    # Verifica si tiene dos casillas con valores diferentes a 9 en la misma fila, columna o diagonal
    print("has_consecutive:",has_consecutive(grid, row, col),"\n%%%%%%%%%%%%%%%%%%%%%%")
    if has_consecutive(grid, row, col):
        for num in range(0, 9):
            print("num:",num)
            print("is valid:",is_valid(grid, num, row, col))
            if is_valid(grid, num, row, col):# verifico que no esté repetido
                
                
                if check_sum(grid,num, row, col):
                    grid[row][col] = num
                    replace_any_with_9(grid)
                                  
                    print("llamada recursiva al backtracking con grid: \n")
                    for r in grid:
                        print(r)
                    print()
                    if solve(grid):
                        print("entra al true final")
                        return True  # Se encontró una solución
                    #'''
                    
                    print("retrocede")
                    replace_any_with_9(grid)
                    
                    print("grid despues de salir de backtracking")
                    for r in grid:
                        print(r)
                    #'''    
                    grid[row][col] = 9  # Si no lleva a una solución, retrocede
    
    
    
    return False  # No hay solución con la configuración actual


############################______________P01_________________##############################
grid = [
    [3, 9, 9],
    [9, 4, 9],
    [9, 6, 5],
]


#grid = [
#    [3, 2, 7],
#    [8, 4, 0],
#    [1, 6, 5],
#]
'''
############################______________P04_________________##############################
grid = [
    [9, 9, 9],
    [9, 9, 8],
    [5, 6, 1],
]


#grid = [
#    [7, 2, 3],
#    [0, 4, 8],
#    [5, 6, 1],
#]
'''


def main():
   # Imprime el cuadrado mágico resuelto
    print("Matriz original:")
    for row in grid:
        print(row)

    if solve(grid):
        print("\nMatriz solucionada:")
        for row in grid: # es el grid "retornado de la funcion " sacado de su memoria local
            print(row)
    else:
        print("\nNo se pudo resolver la matriz.")    

if __name__ == "__main__":
    main()

# %%
Asesoria #6

cuales eran las condiciones para resolver el problema

1. debo representar los espacios vacios con algo porque se llena el cuadrado con los numeros del 0 al 9

2. hacer una funcion que verifique que los numeros estan disponibles (no repetidos)
3. la suma de todos los elementos de cada fila debe ser igual a 12
4. la suma de todos los elementos de cada columna debe ser igual a 12
5. la suma de todos los elementos de la diagonal principal debe ser igual a 12
6. la suma de todos los elementos de la diagonal invertida debe ser igual a 12

7. al momento de sumar cambiar bien la representacion del espacio vacio para no generar un falso 12
8. definir una funcion que comprobara si las otras 2 casillas de la fila, columna o diagonal son 12
9. definir una ffuncion que encuentre las coordenadas de espacios vacios para saltar de uno a otro "ignorando" el backtracking

# %%
grid = [
    [3, 9, 9],
    [9, 4, 9],
    [9, 6, 5],
]

print(9 not in grid[0][:1] + grid[0][1 + 1:])
print(grid[0][:1])
print( grid[0][1 + 1:])
print( grid[0][:1] + grid[0][1 + 1:])

# %%
para p04 en el check sum añadir la comprobacion a la diagonal

# %%
# jhuomar


import tkinter as tk
import itertools

def is_valid(square, row, col, num):
    # Verifica si el número num se puede colocar en la posición (row, col) del cuadrado mágico square
    for i in range(3):
        if square[row][i] == num or square[i][col] == num:
            return False
    if row == col:
        if square[0][0] == num or square[1][1] == num or square[2][2] == num:
            return False
    if row + col == 2:
        if square[0][2] == num or square[1][1] == num or square[2][0] == num:
            return False
    return True

def solve_magic_square_with_partial(square):
    # Función para resolver el cuadrado mágico basado en un cuadro parcialmente completado
    def backtrack(row, col):
        if row == 3:
            return True
        if square[row][col] != '_':
            return backtrack(row + 1 if col == 2 else row, (col + 1) % 3)
        for num in range(1, 10):
            if is_valid(square, row, col, num):
                square[row][col] = num
                if backtrack(row + 1 if col == 2 else row, (col + 1) % 3):
                    return True
                square[row][col] = '_'
        return False

    # Llama al backtracking con las coordenadas iniciales
    backtrack(0, 0)
    return square

def check_magic_square(square):
    # Verifica si el cuadrado mágico cumple con la suma de filas, columnas y diagonales igual a 12
    for i in range(3):
        if sum(square[i]) != 12:
            return False
        col_sum = sum(square[j][i] for j in range(3))
        if col_sum != 12:
            return False
    if square[0][0] + square[1][1] + square[2][2] != 12:
        return False
    if square[0][2] + square[1][1] + square[2][0] != 12:
        return False
    return True

def obtener_valores_faltantes(partial_square):
    # Resolver cuadrado mágico y obtener los valores faltantes
    return solve_magic_square_with_partial(partial_square)

def mostrar_interfaz_grafica(result):
    root = tk.Tk()
    root.title("Cuadrado Mágico")

    for i in range(3):
        for j in range(3):
            label = tk.Label(root, text=result[i][j], font=('Helvetica', 16), width=5, height=2, relief="solid")
            label.grid(row=i, column=j, padx=5, pady=5)

    root.mainloop()

# Cuadrado mágico parcialmente completado
#partial_square = [[3, '_', '_'], ['_', 4, '_'], ['_', 6, 5]]
partial_square = [['_', '_', '_'], ['_', '_', 8], [5, 6, 1]]


# Generar todas las permutaciones posibles de los números del 0 al 8
permutations = itertools.permutations(range(9))

# Buscar la primera permutación que forme un cuadrado mágico válido
result = None
for perm in permutations:
    square = [[perm[j * 3 + i] for i in range(3)] for j in range(3)]
    if check_magic_square(square):
        result = square
        break

# Mostrar interfaz gráfica
if result:
    mostrar_interfaz_grafica(result)
else:
    print("No se pudo completar el cuadrado mágico.")
