# %% [markdown]
# # Coding and Programming
#
# ## Capítulo 5
#
# ### Algoritmos de clasificación
#
# - **Unidad 27.** Ordenamiento de burbuja, (Bubble Sort) algoritmo de ordenamiento, selección e inserción
# - **Unidad 28.** Ordenar por selección, ordenamiento por inserción.
# - **Unidad 29.** Clasificación rápida

# %% [markdown]
# ___

# %% [markdown]
# ## Q 27-01
#
# ¿Cuántas comparaciones se ejecutaron en el siguiente proceso de ordenamiento de burbuja?
# ```
# def bubbleSort(S):
#     n = len(S)
#     for i in range(n):
#         print(S)
#         for j in range(n-1):
#             if S[j] > S[j+1]:
#                S[j] , S[j+1] = S[j+1] , S[j]
#
# S = [50, 30, 40, 10, 20]
# bubbleSort(S)
# print(S)
# ```
# #### Output
# ```
# [50, 30, 40, 10, 20]
# [30, 40, 10, 20, 50]
# [30, 10, 20, 40, 50]
# [10, 20, 30, 40, 50]
# [10, 20, 30, 40, 50]
# [10, 20, 30, 40, 50]
# ```

# %%
def bubbleSort(S):
    n = len(S)
    comp=0
    cam=0
    #print(list(range(n)))
    for i in range(n):
        print(S)
        for j in range(n-1):
            comp+=1           
            if S[j] > S[j+1]:
                cam+=1            
                S[j] , S[j+1] = S[j+1] , S[j]
    print(f"se realizaron {comp} comparaciones")
    print(f"se realizaron {cam*2} movimientos")

S = [50, 30, 40, 10, 20]
bubbleSort(S)
print(S)

'''
n=5
i= [0, 1, 2, 3, 4]       j= [0, 1, 2, 3]

__________________________________________________
i=0

j=0
50>30:
s=[30, 50, 40, 10, 20]

j=1 
50>40
s=[30, 40, 50, 10, 20]

j=2
50>10
s=[30, 40, 10, 50, 20]

j=3
50>20
s=[30, 40, 10, 20, 50]

j=4
______________________________
i= 1

j=0
30>40
s=[30, 40, 10, 20, 50]

j=1
40>10
s=[30, 10, 40, 20, 50]

j=2
40>20
s=[30, 10, 20, 40, 50]

j=3
40>50
s=[30, 10, 20, 40, 50]
______________________________
i= 2
j=0
30>10
s=[10, 30, 20, 40, 50]

j=1
30>20
s=[10, 20, 30, 40, 50]

j=2
30>40
s=[10, 20, 30, 40, 50]

j=3
40>50
s=[10, 20, 30, 40, 50]

______________________________
i= 3
j= 0
10>20
s=[10, 20, 30, 40, 50]

j= 1
20>30
s=[10, 20, 30, 40, 50]

j= 2
30>40
s=[10, 20, 30, 40, 50]

j= 3
40>50
s=[10, 20, 30, 40, 50]
______________________________
i= 4

j= 0
10>20
s=[10, 20, 30, 40, 50]

j= 1
20>30
s=[10, 20, 30, 40, 50]

j= 2
30>40
s=[10, 20, 30, 40, 50]

j= 3
40>50
s=[10, 20, 30, 40, 50]

* observacion IMPORTANTE

En el ordenamiento tipo burbuja pueden sobrar comparaciones, 

en i=2 ya habia ordenado


*********************** comparaciones***********************************
¿Cuántas comparaciones se ejecutaron en el siguiente proceso de ordenamiento de burbuja?

Se realizaron 20 comparaciones

*********************** movimientos ***********************************
¿Cuántos movimientos se ejecutaron en el siguiente proceso de ordenamiento de burbuja?

se realizaron 8 cambios

'''
print()
# Out:
# [50, 30, 40, 10, 20]
# [30, 40, 10, 20, 50]
# [30, 10, 20, 40, 50]
# [10, 20, 30, 40, 50]
# [10, 20, 30, 40, 50]
# se realizaron 20 comparaciones
# se realizaron 16 movimientos
# [10, 20, 30, 40, 50]

# %% [markdown]
# ___

# %% [markdown]
# ## Q 27-02
#
# ¿Cuántas comparaciones se ejecutaron en el siguiente proceso de ordenamiento de inserción?
# ```
# def insertionSort2(S):
#     n = len(S)
#     for i in range(1,n):
#         print(S)
#         x = S[i]
#         j = i - 1
#         while j >= 0 and S[j] > x:
#             S[j+1] = S[j]
#             j -= 1
#         S[j + 1] = x
#
# S = [50, 30, 40, 10, 20]
# insertionSort2(S)
# print(S)
# ```
# #### Output
# ```
# [50, 30, 40, 10, 20]
# [30, 40, 10, 20, 50]
# [30, 10, 20, 40, 50]
# [10, 20, 30, 40, 50]
# [10, 20, 30, 40, 50]
# [10, 20, 30, 40, 50]
# ```

# %%
def insertionSort2(S):
    n = len(S)
    comp=0
    cam=0
    #print(list(range(1,n)))
    for i in range(1,n):
        print(S)
        x = S[i]
        j = i - 1
        comp+=2
        while j >= 0 and S[j] > x:
            comp+=2
            S[j+1] = S[j]
            cam+=1
            j -= 1
        S[j + 1] = x
        cam+=1
    print(f"se realizaron {comp} comparaciones")
    print(f"se realizaron {cam} movimientos")

S = [50, 30, 40, 10, 20]
insertionSort2(S)
print(S)
'''
i = [1, 2, 3, 4]
___________________________________
i=1
S = [50, 30, 40, 10, 20]
x= 30
j=0
s[0]=50 > 30
*******
S = [50, 50, 40, 10, 20]
j= -1
*******
S = [30, 50, 40, 10, 20]
___________________________________
i=2
x=40
j=1 = 50 >40
******
S = [30, 50, 50, 10, 20]
j=0
s[0]=30 > 40
******
S = [30, 40, 50, 10, 20]

x=10
j=2
s[2]=50 >10
******
S = [30, 40, 50, 50, 20]
j=1

***
S = [30, 40, 40, 50, 20]
j=0
s[0]=30 >10

**
S = [30, 30, 40, 50, 20]
j=-1
**
***
******
S = [10, 30, 40, 50, 20]
___________________________________
i=4
x=20
j=3
s[3]=50 >20
*******
20 se va a mover 4 espacios a la izquierda
es decir, va a entrar en el while 4 veces

*******

*****************************conclusiones*********************************

se hacen tantas comparaciones *2  como veces entre en el while
se hacen tantos cambios como veces entre el el while + los cambios de la linea 19



'''

print()
# Out:
# [50, 30, 40, 10, 20]
# [30, 50, 40, 10, 20]
# [30, 40, 50, 10, 20]
# [10, 30, 40, 50, 20]
# se realizazon 24 comparaciones
# se realizazon 12 movimientos
# [10, 20, 30, 40, 50]

# %% [markdown]
# ___

# %% [markdown]
# ## Q 28-01
#
# ¿Cuántas veces se ejecuta la función `merge2()` en el siguiente proceso de ordenamiento por fusión?
# ```
# S = [6,2,11,7,5,4,8,16,10,3]
# mergeSort2(S, 0, len(S)-1)
# print(S)
# ```

# %%
usage=0


def merge2(s, low, mid, high):
    global usage
    
    R = []
    i, j = low, mid + 1
    while i <= mid and j <= high:
        
        if s[i] < s[j]:
            R.append(s[i]); i += 1
        else:
            R.append(s[j]); j += 1
        
    
    if i > mid:
        for k in range(i, mid + 1):
            R.append(s[j])
    else:
        for k in range(i, mid + 1):
            R.append(s[i])
    for k in range(len(R)):
        s[low + k] = R[k] 
        
    usage+=1
    

def mergeSort2(s, low, high):
    if low < high:
        print(s)
        mid = (low + high) // 2
        mergeSort2(s, low, mid)
        mergeSort2(s, mid + 1, high)
        merge2(s, low, mid, high)
    
S = [6,2,11,7,5,4,8,16,10,3]        

mergeSort2(S, 0, len(S)-1)
print(S)        
print(f"se llamó merge2 {usage} veces")
# Out:
# [6, 2, 11, 7, 5, 4, 8, 16, 10, 3]
# [6, 2, 11, 7, 5, 4, 8, 16, 10, 3]
# [6, 2, 11, 7, 5, 4, 8, 16, 10, 3]
# [6, 2, 11, 7, 5, 4, 8, 16, 10, 3]
# [2, 6, 11, 7, 5, 4, 8, 16, 10, 3]
# [2, 5, 6, 7, 11, 4, 8, 16, 10, 3]
# [2, 5, 6, 7, 11, 4, 8, 16, 10, 3]
# [2, 5, 6, 7, 11, 4, 8, 16, 10, 3]
# [2, 5, 6, 7, 11, 4, 8, 16, 10, 3]
# [2, 3, 4, 5, 6, 7, 8, 10, 11, 16]
# se llamó merge2 9 veces

# %% [markdown]
# # trabajo extra del profe

# %%
usage=0
comp=0
cam=0

def merge2(s, low, mid, high):
    global usage
    global comp
    
    R = []
    i, j = low, mid + 1
    while i <= mid and j <= high:
        comp+=3
        if s[i] < s[j]:
            R.append(s[i]); i += 1
        else:
            R.append(s[j]); j += 1
    comp+=1    
    if i > mid:
        for k in range(i, mid + 1):
            R.append(s[j])
    else:
        for k in range(i, mid + 1):
            R.append(s[i])
    for k in range(len(R)):
        s[low + k] = R[k] 
        
    usage+=1
    

def mergeSort2(s, low, high):
    if low < high:
        print(s)
        mid = (low + high) // 2
        mergeSort2(s, low, mid)
        mergeSort2(s, mid + 1, high)
        merge2(s, low, mid, high)
    
        
S = [50, 30, 40, 10, 20]
mergeSort2(S, 0, len(S)-1)
print(S)        
print(f"se llamó merge2 {usage} veces")
print(f"se realizaron {comp} comparaciones")
print(f"se realizaron {cam} movimientos")
# Out:
# [50, 30, 40, 10, 20]
# [50, 30, 40, 10, 20]
# [50, 30, 40, 10, 20]
# [30, 40, 50, 10, 20]
# [10, 20, 30, 30, 30]
# se llamó merge2 4 veces
# se realizaron 22 comparaciones
# se realizaron 0 movimientos

# %% [markdown]
# ## Q 29-01
#
# Dada la lista a continuación, escriba la salida después de ejecutar la función `partition1()`
# ```
# S = [15,10,12,20,25,13,22]
# partition1(S, 0, len(S)-1)
# print(S)
# ```
# #### Output
# ```
# [15,10,12,20,25,13,22] 0 6 pivot = 15
# ...
# ```

# %%
def partition1(s, low, high):
    pivot = s[low]
    left, right = low + 1, high
    while left < right:
        print(s)
        while left <= right and s[left] <= pivot:
            left += 1
        while left <= right and s[right] >= pivot:
            right -= 1
        if left < right:
            s[left], s[right] = s[right], s[left]
    pivotpoint = right
    s[low], s[pivotpoint] = s[pivotpoint], s[low]
    return low, high, pivotpoint

S = [15,10,12,20,25,13,22]
low, high, pivot = partition1(S, 0, len(S)-1)
print("{} {} {} pivot = {}" .format(S, low, high, S[pivot]))
print(S)
# Out:
# [15, 10, 12, 20, 25, 13, 22]
# [15, 10, 12, 13, 25, 20, 22]
# [13, 10, 12, 15, 25, 20, 22] 0 6 pivot = 15
# [13, 10, 12, 15, 25, 20, 22]

# %% [markdown]
# # trabajo extra del profe

# %%
comp=0
cam=0

def partition1(s, low, high):
    global comp
    global cam
    
    pivot = s[low]
    left, right = low + 1, high
    while left < right:
        comp+=1
        print(s)
        while left <= right and s[left] <= pivot:
            comp+=2
            left += 1
        while left <= right and s[right] >= pivot:
            comp+=2
            right -= 1
        if left < right:
            comp+=1
            s[left], s[right] = s[right], s[left]
            cam+=2
    pivotpoint = right
    s[low], s[pivotpoint] = s[pivotpoint], s[low]
    cam+=2
    return  pivotpoint


def quicksort2(S,low,high):
    if low < high:
        pivotpoint = partition1(S,low,high)
        quicksort2(S,low,pivotpoint-1)
        quicksort2(S,pivotpoint+1,high)

S = [50, 30, 40, 10, 20]
quicksort2(S, 0, len(S)-1)

#low, high, pivot = partition1(S, 0, len(S)-1)
#print("{} {} {} pivot = {}" .format(S, low, high, S[pivot]))
print(S)     

print(f"se realizaron {comp} comparaciones")
print(f"se realizaron {cam} movimientos")
# Out:
# [50, 30, 40, 10, 20]
# [20, 30, 40, 10, 50]
# [20, 10, 40, 30, 50]
# [10, 20, 30, 40, 50]
# se realizaron 18 comparaciones
# se realizaron 8 movimientos

# %% [markdown]
# ## conclusion final
# para S = [50, 30, 40, 10, 20]
#
# * metodo de ordenamietno tipo burbuja
#
# se realizaron 20 comparaciones
# se realizaron 16 movimientos
# procesos=36
#
#
# * metodo de ordenamiento por insercion
#
# se realizazon 24 comparaciones
# se realizazon 12 movimientos
# procesos=36
#
# * metodo de ordenamiento por fusion
#
# se realizaron 22 comparaciones
# se realizaron 0 movimientos
#
# procesos=22
#
# * metodo de ordenamiento por quick sort
#
# se realizaron 18 comparaciones
# se realizaron 8 movimientos
#
# procesos= 26

# %% [markdown]
# # Fin
