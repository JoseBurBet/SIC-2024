# %% [markdown]
# ### FUNCIONES

# %% [markdown]
# como programador defino funciones que voy a reutilizar en el codigo
# tenemos una funcion llamada print() dentro del python base
#
# una funcion tiene:
# * nombre -> palabra reservada
# * ()
# * argumentos -> son lo que necesito para que cumpla su funcion
# * retorno -> lel resultado de lo que haga la funcion
#
# cuando empleo funciones recuerdo 4 cosas:
# 1. DEFINIR -> crearla
# 2. defino si tiene entradas (ARGUMENTOS)
# 3. DEFINO SI TIENE SALIDAS (RETORNO)
# 4. invocar o llamar la funcion (UTILIZARLA)

# %% [markdown]
# ### A TENER EN CUENTA CUANDO ESTOY DESARROLLANDO CODIGO
#
# #################################################
# readme.txt -> version del lenguaje
#               version de las librerias
#               que hace el codigo
#               quien lo creo
#               COMO SE EJECUTA!
#
#
# /////////////////////////////////////////////////////////////
# fecha
# DESCRIPCION DE LO QUE HACE EL CÓDIGO
# QUIEN LO CREO
# /////////////////////////////////////////////////////////////
# VARIABLES GLOBALES -> CONSTANTES
# ///////////////////////////////////////////////////////////
# FUNCIONES
# //////////////////////////////////////////////////////////////
# FUNCION MAIN

# %%
# Ejemplo de funcion sencilla


#/////////////////////////////////////////////////////////////
# sumadora sencilla
# profe jose ejemplo de clase
#/////////////////////////////////////////////////////////////
# no variables constantes
#/////////////////////////////////////////////////////////////

#funcion
def suma(numero1,numero2):
    suma=numero1+numero2
    return suma



#/////////////////////////////////////////////////////////////
# main

continuar= True
while continuar == True:
    n1=int(input("ingrese n1: "))
    n2=int(input("ingrese n2: "))
    resultado=suma(n1,n2) 
    resultado2=suma(n1+2,n+2)
    
    print(f" {n1} + {n2} = {resultado}")
    
    salir=input("Desea continuar? \n si. \n no. \n")
    if salir=="si":
        continuar=True
    elif salir == "no":
        continuar = False
    else:
        print("ingrese si, o no ")

# %% [markdown]
# ### ejemplo de como puedo convertir varios archivos de python en "librerias" y llamar sus funciones dentro de un archivo main
#
# readme:
#
# este es un cajero sencillo realizado en python 3.9.7

# %%
# main.PY 

# clase#5
# prof jose
# ejemplo de un codigo mejor hecho
# cajero sencillo

######################## MAIN ##############3

def main():
    
    constructor_json()
    login=acceso()
    
    if login==True:
        saldo=contultar()
        print(saldo)
        

control de acceso
memoria -> dinero , usuario , contraseña
consulta
retira
ingresar
#transferencia


from memoria import constructor_json
from acceso import  acceso
import opciones 

if __name__ == '__main__':
    main()

# %%
# memoria.py -> crear la memoria.json

# clase#5
# prof jose
# constructor de la memoria para el banco - database

#un driver de un archi de python inicializa el código permitiendo
#que sea llamado desde otro archivo de python 



def constructor_json():

    data='{"dinero":10000,"user":"jose","password":"python"}'
    json_data=json.loads(data)

    #generar el archivo json
    with open('data_banco.json','w') as f: #w-> write para modo escritura
        json.dump(json_data,f,indent='\t')

        
#__________________________________Main________________________


#driver 
import json

if __name__ == '__main__':
    constructor_json()

# %%
# acceso.py

def acceso():
    
    #defino si esta bien el usuario y contraseña y brindo acceso al código
    
if __name__ == '__main__':
    acceso()

# %%
#opciones.py

def consulta():
    
def retiro():
    
def ingreso():
    
    
def main():
    print_menu():
    op=input("seleccione una opcion:")
    if op==1:
        consulta()
    elif op==2:
        retiro()
            
    
#driver
if __name__ == '__main__':
    #main()

# %% [markdown]
# # programacion orientada a objetos POO
#
# * clases: es un algo que encierra un conjunto de objetos-> sirve para catalogar
# ejemplo medios de transporte
# class medios_de_transporte:
#
# * subclase: es una clase que pertenece a una clase mayor
# ejmplo
# class automotores_4_ruedas
# class dos_ruedas
# Class maritimos
# class aereos
#
#
# * objetos: es un elemento(INSTANCIA) que pertenece a una clase y posee unos atributos
#
# objetos de la clase medios de transporte :
#
# camioneta
# carro
#
# moto
# bicicleta
#
# barco
#
# helicoptero
# globo
#
# * atributos : elemento que puede diferenciar un objeto de otro aunque pertenezca a la misma clase
#
# ejemplo
# tamaño
# marca
# color
# potencia hp
#
# pueden tener atributos en comun o no
#
#
# * metodos: una funcion que pertenece a una clase  se llama metodo
#
#
# * constructores: inicializa/crea /hace que exista el objeto de la clase y le asigna los atributos correspondientes a su clase
#
#
# * jerarquia o herencia : existe un orden hay cosas que se pueden heredar
#
# ejemplo
#
# clase_medios de tranporte      abuelo
# clase_vehiculos de 4 ruedas    papa
# camioneta                      niño
#
# se heredan atributos , variables y metodos
#
# siempre puedo utilizar lo que se ha heredado
#
#
# * autoparametros SELF: PUNTERO, el codigo entiende a quien esta operando  y toma sus valores o atributos correspondientes sin necesidad de especificar que objeto es
#
# def imprimmir_color(objeto):
#     print(self.color)
