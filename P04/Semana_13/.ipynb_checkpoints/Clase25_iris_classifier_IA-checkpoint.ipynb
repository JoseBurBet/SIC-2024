# %% [markdown]
# # Abrir y usar el modelo

# %%
import pickle
f=open("modelo_final.pickle","rb")
load_model=pickle.load(f)

# %%
# el sigueinte paso seria ingresar la data que se queire pedecir

from IPython.core.display import HTML
from sklearn.datasets import load_iris

# cargo la "nueva" data a la que aplicaré ML para clasificar
datos=load_iris()
datos.data
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
# hago la prediccion

predicted_species=load_model.predict(datos.data)
# Out:
# C:\Users\joseb\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd

#datos["data"]
#datos.data
# feature_names -> nombres de las columnas de la data
data_df=pd.DataFrame(data=datos.data,columns=datos.feature_names)
#display(HTML(data_df.to_html()))

target=pd.DataFrame(data=predicted_species,columns=["species"])
#display(HTML(target.to_html()))

iris=pd.concat([data_df,target],axis=1)
display(HTML(iris.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sepal length (cm)</th>
#       <th>sepal width (cm)</th>
#       <th>petal length (cm)</th>
#       <th>petal width (cm)</th>
#       <th>species</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>5.1</td>
#       <td>3.5</td>
#       <td>1.4</td>
#       <td>0.2</td>
#       <td>setosa</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4.9</td>
#       <td>3.0</td>
#       <td>1.4</td>
#       <td>0.2</td>
#       <td>setosa</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4.7</td>
#       <td>3.2</td>
#       <td>1.3</td>
#       <td>0.2</td>
#       <td>setosa</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4.6</td>
#       <td>3.1</td>
#       <td>1.5</td>
#       <td>0.2</td>
#       <td>setosa</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5.0</td>
#       <td>3.6</td>
#       <td>1.4</td>
# ...

# %%
#Guardando los dataframes en un archivo .csv

from datetime import datetime

date = datetime.now().strftime("%d-%m-%Y")

def guardarCSV(df, nombre, fecha):
    nombre = nombre + "_" + fecha + '.csv'
    print(nombre)
    df.to_csv(nombre, index = True)
    
guardarCSV(iris,"Predicciones_Iris",date)
# Out:
# Predicciones_Iris_23-04-2024.csv
